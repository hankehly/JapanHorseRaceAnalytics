# %%
import functools
import os
import datetime
from typing import List
from pathlib import Path
import re
import pandas as pd
from pyspark.sql import functions as f
from pyspark.sql import SparkSession
from JRDBDataParsingTools.data_schema import load_schema, create_pyspark_schema
from JRDBDataParsingTools.data_parser import parse_line
from JRDBDataParsingTools.file_downloader import download_and_extract_files
from JRDBDataParsingTools.structured_logger import logger

# %%
# %load_ext dotenv

# %% [markdown]
# # Download files from the web

# %%
# JRDB credentials
username = os.getenv("JRDB_USERNAME")
password = os.getenv("JRDB_PASSWORD")
# The directory where you want to download the files
# Must be an absolute path
download_dir = "/Users/hankehly/Projects/JRDBDataParsingTools/downloads"

# %%
target_dataset_urls = [
    # Taken from http://www.jrdb.com/member/dataindex.html
    # Comment out the ones you don't want to download.
    # Downloading all of them will take about ?
    "http://www.jrdb.com/member/datazip/Kab/index.html",
    "http://www.jrdb.com/member/datazip/Bac/index.html",
    "http://www.jrdb.com/member/datazip/Kyi/index.html",
    "http://www.jrdb.com/member/datazip/Ukc/index.html",
    "http://www.jrdb.com/member/datazip/Oz/index.html",
    # "http://www.jrdb.com/member/datazip/Oz/index2.html",  # OW data
    # "http://www.jrdb.com/member/datazip/Ou/index.html",
    # "http://www.jrdb.com/member/datazip/Ot/index.html",
    # "http://www.jrdb.com/member/datazip/Ov/index.html",
    "http://www.jrdb.com/member/datazip/Cyb/index.html",
    "http://www.jrdb.com/member/datazip/Cha/index.html",
    "http://www.jrdb.com/member/datazip/Sed/index.html",
    "http://www.jrdb.com/member/datazip/Skb/index.html",
    "http://www.jrdb.com/member/datazip/Tyb/index.html",
    "http://www.jrdb.com/member/datazip/Hjc/index.html",
]

for webpage_url in target_dataset_urls:
    download_and_extract_files(
        webpage_url, username, password, download_dir, start_date=datetime.date(2023, 12, 1)
    )
# Out:
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Kab/index.html", "level": "info", "timestamp": "2023-12-30T19:01:21.038827Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2024/KAB240108.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.536576Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2024/KAB240107.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.536866Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2024/KAB240106.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.537184Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.537337Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.537508Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.538644Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.539093Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.539549Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.540483Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.540953Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.541072Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.541536Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Bac/index.html", "level": "info", "timestamp": "2023-12-30T19:01:24.463461Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2024/BAC240108.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.449997Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2024/BAC240107.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450304Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2024/BAC240106.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450446Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450708Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450835Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451342Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451466Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451764Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451968Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.452138Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.452308Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.452433Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Kyi/index.html", "level": "info", "timestamp": "2023-12-30T19:01:27.081532Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564022Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564555Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564689Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564824Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565300Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565565Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565776Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565912Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.566014Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Ukc/index.html", "level": "info", "timestamp": "2023-12-30T19:01:31.663553Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2024/UKC240108.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.275389Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2024/UKC240107.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.275679Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2024/UKC240106.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.275816Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.276109Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.276235Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.276361Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277029Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277233Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277375Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277473Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.278017Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.278209Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Oz/index.html", "level": "info", "timestamp": "2023-12-30T19:01:35.616693Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140134Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140418Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140610Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140866Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.141653Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.142010Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.142935Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.143881Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.144314Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Cyb/index.html", "level": "info", "timestamp": "2023-12-30T19:01:38.967666Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.072316Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.072590Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.072811Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073068Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073214Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073329Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073881Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.074097Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.074278Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Cha/index.html", "level": "info", "timestamp": "2023-12-30T19:01:41.712181Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593236Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593491Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593598Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593884Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.594100Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.594788Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.595353Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.595519Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.595776Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Sed/index.html", "level": "info", "timestamp": "2023-12-30T19:01:44.427840Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.432807Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433200Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433415Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433629Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433754Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433853Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.434403Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.434718Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.434899Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Skb/index.html", "level": "info", "timestamp": "2023-12-30T19:01:48.158133Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.890516Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.890997Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.891325Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.891962Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892219Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892396Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892580Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892825Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Tyb/index.html", "level": "info", "timestamp": "2023-12-30T19:01:57.157213Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.520607Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.520861Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521138Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521276Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521455Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521895Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.522230Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.522534Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.523686Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Hjc/index.html", "level": "info", "timestamp": "2023-12-30T19:02:00.453931Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231228.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.975878Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231224.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976164Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231223.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976308Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231217.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976553Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231216.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976674Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231210.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976843Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231209.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.977245Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231203.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.977676Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231202.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.978182Z", "logger": "JRDBDataParsingTools.file_downloader"}

# %% [markdown]
# # Record which files were downloaded

# %%
from pyspark.sql.types import StringType


spark = SparkSession.builder.config("spark.jars", "postgresql-42.7.1.jar").getOrCreate()

spark.createDataFrame(os.listdir(download_dir), StringType()).write.mode("overwrite").format("jdbc").options(
    url="jdbc:postgresql://localhost:5432/jrdb",
    user="admin",
    password="admin",
    driver="org.postgresql.Driver",
    dbtable="jrdb_raw.processed_files",
).save()

# %% [markdown]
# # Import data into Postgres

# %% [markdown]
# ## Todo: incremental processing

# %%
# df_processed_files = (
#     spark.read.jdbc(
#         url="jdbc:postgresql://localhost:5432/jrdb",
#         table="jrdb_raw.processed_files",
#         properties={
#             "user": "admin",
#             "password": "admin",
#             "driver": "org.postgresql.Driver",
#         },
#     )
#     .alias("df_processed_files")
#     .select("value")
# )

# df_data = (
#     spark.read.format("binaryFile")
#     .load("file:///Users/hankehly/Projects/JRDBDataParsingTools/downloads/BAC*.txt")
#     .withColumn("filename", f.element_at(f.split(f.col("path"), "/"), -1))
#     # .rdd.flatMap(lambda x: x[0].splitlines())
#     # .show(truncate=False)
# )

# unprocessed_files = df_data.join(df_processed_files, df_data.filename == df_processed_files.value, "left_anti")

# unprocessed_files.show(truncate=False)
# Out:
# +------------------------------------------------------------------------------+-----------------------+------+-------------------+-----------------+
# |path                                                                          |modificationTime       |length|content            |filename         |
# +------------------------------------------------------------------------------+-----------------------+------+-------------------+-----------------+
# |file:/Users/hankehly/Projects/JRDBDataParsingTools/downloads/BAChelloworld.txt|2023-12-30 13:33:58.427|6     |[68 65 6C 6C 6F 0A]|BAChelloworld.txt|
# +------------------------------------------------------------------------------+-----------------------+------+-------------------+-----------------+

# %%
def etl(spark, schema_path: str, data_path: str | List[str], dbtable: str, surrogate_key_name: str):
    logger.info(f"Processing dataset {dbtable}")
    schema = load_schema(schema_path)
    logger.info("Creating PySpark DataFrame")
    df = (
        spark.read.format("binaryFile")
        .load(data_path)
        .select("content")
        .rdd.flatMap(lambda x: x[0].splitlines())
        .map(functools.partial(parse_line, schema=schema))
        .toDF(create_pyspark_schema(schema))
        # Todo: monotonic increasing id does not mean files with lower dates will have lower ids!
        .withColumn(surrogate_key_name, f.monotonically_increasing_id())
        # Returns the wrong file name..
        # .withColumn("input_file_name", f.input_file_name())
    )
    logger.info("Writing to data warehouse")
    (
        df.write.mode("overwrite")
        .format("jdbc")
        .options(
            url="jdbc:postgresql://localhost:5432/jrdb",
            user="admin",
            password="admin",
            driver="org.postgresql.Driver",
            dbtable=dbtable,
        )
        .save()
    )

# %%
schema_name = "jrdb_raw"

datasets = [
    "KAB",
    "BAC",
    "KYI",
    "UKC",
    "OZ",
    "OW",
    "OU",
    "OT",
    "OV",
    "CYB",
    "CHA",
    "SKB",
    "HJC",
    "SED", # Run remove_sed_duplicates.sql after loading this dataset
    # "TYB"  # TYB is a special case because the file names are not consistent
]

for dataset in datasets:
    etl(
        spark,
        schema_path=f"schemas/{dataset}.yaml",
        data_path=str(Path(download_dir).joinpath(f"{dataset}*.txt")),
        dbtable=f"{schema_name}.{dataset.lower()}",
        surrogate_key_name=f"{dataset.lower()}_sk",
    )
# Out:
# {"event": "Processing dataset jrdb_raw.kab", "level": "info", "timestamp": "2023-12-30T19:35:18.708335Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:35:18.719002Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:35:22.551348Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.bac", "level": "info", "timestamp": "2023-12-30T19:35:23.828131Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:35:23.838421Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:35:27.677270Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.kyi", "level": "info", "timestamp": "2023-12-30T19:35:29.503706Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:35:29.535871Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:35:33.538578Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.ukc", "level": "info", "timestamp": "2023-12-30T19:36:10.292447Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:36:10.300028Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:36:14.201797Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.oz", "level": "info", "timestamp": "2023-12-30T19:36:23.244544Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:36:23.248921Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:36:26.920085Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.ow", "level": "info", "timestamp": "2023-12-30T19:36:30.138091Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:36:30.141147Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:36:33.695541Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.ou", "level": "info", "timestamp": "2023-12-30T19:36:36.220900Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:36:36.223772Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:36:39.732166Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.ot", "level": "info", "timestamp": "2023-12-30T19:36:43.756308Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:36:43.759027Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:36:47.265180Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.ov", "level": "info", "timestamp": "2023-12-30T19:36:59.386050Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:36:59.391893Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:37:02.534051Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.cyb", "level": "info", "timestamp": "2023-12-30T19:37:58.911648Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:37:58.918974Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:38:03.206134Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.cha", "level": "info", "timestamp": "2023-12-30T19:38:11.352173Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:38:11.358953Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:38:14.057164Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.skb", "level": "info", "timestamp": "2023-12-30T19:38:18.993419Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:38:19.000201Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:38:22.923383Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.hjc", "level": "info", "timestamp": "2023-12-30T19:38:38.401202Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:38:38.405414Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:38:42.226435Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Processing dataset jrdb_raw.sed", "level": "info", "timestamp": "2023-12-30T19:38:44.343763Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:38:44.363917Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:38:48.295711Z", "logger": "JRDBDataParsingTools.file_downloader"}

# %% [markdown]
# # Handle edge cases in TYB files before loading into Postgres
#
# The following TYB file in the annual pack contains null byte characters. Its daily file counterpart does not, so we must replace it before the file can be processed.
# * TYB060121.txt
#
# Starting 2021-09-04, TYB files are duplicated in the annual pack. One file name contains a "_t" while the other does not. The daily file counterpart contains the same information as the annual pack file whose name does not contain a "_t" in it. In addition, some of the "_t" files contain null byte characters. The following files are affected. All files with "_t" in the name are ignored when parsing.
# * TYB210904_t.txt
# * TYB210905_t.txt
# * TYB210911_t.txt

# %%
# TYB is a special case because the file names are not consistent
tyb_pattern = re.compile(r"TYB\d{6}\.txt$")
tyb_files_glob = Path(download_dir).glob("TYB*.txt")
tyb_files = [str(file) for file in tyb_files_glob if tyb_pattern.match(file.name)]
etl(
    spark,
    schema_path="schemas/TYB.yaml",
    data_path=tyb_files,
    dbtable=f"{schema_name}.tyb",
    surrogate_key_name="tyb_sk",
)
# Out:
# {"event": "Processing dataset jrdb_raw.tyb", "level": "info", "timestamp": "2023-12-30T19:39:10.204734Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2023-12-30T19:39:10.213372Z", "logger": "JRDBDataParsingTools.file_downloader"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2023-12-30T19:39:13.528919Z", "logger": "JRDBDataParsingTools.file_downloader"}

# %% [markdown]
# # Convert codes to CSV format
#
# Copy and paste text from the code web pages into the following block, run cell, and save as a CSV file in the `seeds` directory.
#
# * [ＪＲＤＢデータコード表](http://www.jrdb.com/program/jrdb_code.txt)
# * [脚元コード表（2017.02.20）](http://www.jrdb.com/program/ashimoto_code.txt)
# * [馬具コード表（2017.07.02）](http://www.jrdb.com/program/bagu_code.txt)
# * [特記コード表（2008.02.23）](http://www.jrdb.com/program/tokki_code.txt)
# * [系統コード表（2003.05.15）](http://www.jrdb.com/program/keito_code.txt)
# * [調教コースコード表（2009.10.09）](http://www.jrdb.com/program/cyokyo_course_code.txt)
# * [追い状態コード表（2008.09.28）](http://www.jrdb.com/program/oi_code.txt)

# %%
code_text = """
01      流す
02      余力あり
03      終い抑え
04      一杯
05      バテる
06      伸びる
07      テンのみ
08      鋭く伸び
09      強目
10      終い重点
11      ８分追い
12      追って伸
13      向正面
14      ゲート
15      障害練習
16      中間軽め
17      キリ
21      引っ張る
22      掛かる
23      掛リバテ
24      テン掛る
25      掛り一杯
26      ササル
27      ヨレル
28      バカつく
29      手間取る
99      その他
"""

result = []
for line in code_text.strip().splitlines():
    result.append(line.strip().split())

print(pd.DataFrame(result).to_csv(index=False, header=False))
# Out:
# 01,流す
# 02,余力あり
# 03,終い抑え
# 04,一杯
# 05,バテる
# 06,伸びる
# 07,テンのみ
# 08,鋭く伸び
# 09,強目
# 10,終い重点
# 11,８分追い
# 12,追って伸
# 13,向正面
# 14,ゲート
# 15,障害練習
# 16,中間軽め
# 17,キリ
# 21,引っ張る
# 22,掛かる
# 23,掛リバテ
# 24,テン掛る
# 25,掛り一杯
# 26,ササル
# 27,ヨレル
# 28,バカつく
# 29,手間取る
# 99,その他
