# %%
from pyspark.sql import SparkSession
from JRDBDataParsingTools.parse import decode_cp932, load_schema, parse_text
from pyspark.sql.types import StringType
from pyspark.sql import functions as f


schema_file_path = "schemas/SED.yaml"
data_file_path = "jrdb-data/SED*.txt"
spark = SparkSession.builder.config("spark.jars", "postgresql-42.7.1.jar").getOrCreate()
# Out:
# 23/12/09 17:05:29 WARN Utils: Your hostname, Hanks-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.40.105 instead (on interface en0)
# 23/12/09 17:05:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/12/09 17:05:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = (
    spark.read.format("binaryFile")
    .load(data_file_path)
    .select("content")
    .rdd.flatMap(lambda x: x[0].splitlines())
    .map(decode_cp932)
    .toDF(StringType())
)

# %%
df = parse_text(df, load_schema(schema_file_path)).drop("value").withColumn("input_file_name", f.input_file_name())
df.count()
# Out:
# 838333

# %%
# concat レースキー_場コード|レースキー_年|レースキー_回|レースキー_日|レースキー_Ｒ columns
(
    df
    .withColumn("レースキー", f.concat_ws("", "レースキー_場コード", "レースキー_年", "レースキー_回", "レースキー_日", "レースキー_Ｒ"))
    .select("レースキー")
    .show(truncate=False)
)
# Out:
# +----------+
# |レースキー|
# +----------+
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092701  |
# |06092702  |
# |06092702  |
# |06092702  |
# |06092702  |
# +----------+
# only showing top 20 rows

# %%
df.createOrReplaceTempView("SED")
# Out:
# 23/12/09 17:05:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
spark.sql(
    """
SELECT
  *
FROM
    SED
LIMIT
    10
          """
).show()
# Out:
# +-------------------+-------------+-------------+-------------+-------------+----+-------------------------+-------------------+-------------------------------------+---------------+--------------------------------------+----------------------------+----------------------------+-------------------+---------------+---------------+---------------+---------------+-------------------+-------------------------------+---------------+-----------------------+-----------+---------------+-------------+-----------+-------------+---------------+---------------------+-----------------------+---------------------+-------------------+---------------------+---------------------+-------------------+---------------------+-------------------+---------------------+---------------------+---------------------+---------------------+-------------------------+---------------------------+---------------------------+-------------------------+-------------------------+---------------------------+---------------
# ...

# %%
url = "jdbc:postgresql://localhost:5432/mydatabase"
properties = {"user": "myuser", "password": "mypassword", "driver": "org.postgresql.Driver"}

# Write DataFrame to PostgreSQL table
df.write \
    .format("jdbc") \
    .option("url", url) \
    .option("dbtable", "mytable") \
    .options(**properties) \
    .mode("append") \
    .save()
