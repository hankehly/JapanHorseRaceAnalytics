# %%
import functools
import os
import datetime
from typing import List
from pathlib import Path
import re
import pandas as pd
from pyspark.sql import functions as f
from pyspark.sql import SparkSession
from JapanHorseRaceAnalytics.data.data_schema import load_schema, create_pyspark_schema
from JapanHorseRaceAnalytics.data.data_parser import parse_line
from JapanHorseRaceAnalytics.data.file_downloader import download_and_extract_files
from JapanHorseRaceAnalytics.utilities.structured_logger import logger

# %% [markdown]
# # Download files from the web

# %%
# JRDB credentials
username = os.getenv("JRDB_USERNAME")
password = os.getenv("JRDB_PASSWORD")
# The directory where you want to download the files
# Must be an absolute path
download_dir = "/Users/hankehly/Projects/JapanHorseRaceAnalytics/data/jrdb"

# %%
target_dataset_urls = [
    # Taken from http://www.jrdb.com/member/dataindex.html
    # Comment out the ones you don't want to download.
    # Downloading all of them will take about ?
    "http://www.jrdb.com/member/datazip/Kab/index.html",
    "http://www.jrdb.com/member/datazip/Bac/index.html",
    "http://www.jrdb.com/member/datazip/Kyi/index.html",
    "http://www.jrdb.com/member/datazip/Ukc/index.html",
    "http://www.jrdb.com/member/datazip/Oz/index.html",
    # "http://www.jrdb.com/member/datazip/Oz/index2.html",  # OW data
    # "http://www.jrdb.com/member/datazip/Ou/index.html",
    # "http://www.jrdb.com/member/datazip/Ot/index.html",
    # "http://www.jrdb.com/member/datazip/Ov/index.html",
    "http://www.jrdb.com/member/datazip/Cyb/index.html",
    "http://www.jrdb.com/member/datazip/Cha/index.html",
    "http://www.jrdb.com/member/datazip/Sed/index.html",
    "http://www.jrdb.com/member/datazip/Skb/index.html",
    "http://www.jrdb.com/member/datazip/Tyb/index.html",
    "http://www.jrdb.com/member/datazip/Hjc/index.html",
]

for webpage_url in target_dataset_urls:
    download_and_extract_files(
        webpage_url, username, password, download_dir, start_date=datetime.date(2023, 12, 1)
    )
# Out:
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Kab/index.html", "level": "info", "timestamp": "2023-12-30T19:01:21.038827Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2024/KAB240108.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.536576Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2024/KAB240107.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.536866Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2024/KAB240106.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.537184Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.537337Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.537508Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.538644Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.539093Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.539549Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.540483Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.540953Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.541072Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kab/2023/KAB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:23.541536Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Bac/index.html", "level": "info", "timestamp": "2023-12-30T19:01:24.463461Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2024/BAC240108.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.449997Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2024/BAC240107.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450304Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2024/BAC240106.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450446Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450708Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.450835Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451342Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451466Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451764Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.451968Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.452138Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.452308Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Bac/2023/BAC231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:26.452433Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Kyi/index.html", "level": "info", "timestamp": "2023-12-30T19:01:27.081532Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564022Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564555Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564689Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.564824Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565300Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565565Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565776Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.565912Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Kyi/2023/KYI231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:29.566014Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Ukc/index.html", "level": "info", "timestamp": "2023-12-30T19:01:31.663553Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2024/UKC240108.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.275389Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2024/UKC240107.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.275679Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2024/UKC240106.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.275816Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.276109Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.276235Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.276361Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277029Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277233Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277375Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.277473Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.278017Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Ukc/2023/UKC231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:34.278209Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Oz/index.html", "level": "info", "timestamp": "2023-12-30T19:01:35.616693Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140134Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140418Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140610Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.140866Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.141653Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.142010Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.142935Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.143881Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Oz/2023/OZ231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:38.144314Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Cyb/index.html", "level": "info", "timestamp": "2023-12-30T19:01:38.967666Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.072316Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.072590Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.072811Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073068Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073214Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073329Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.073881Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.074097Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cyb/2023/CYB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:41.074278Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Cha/index.html", "level": "info", "timestamp": "2023-12-30T19:01:41.712181Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593236Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593491Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593598Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.593884Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.594100Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.594788Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.595353Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.595519Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Cha/2023/CHA231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:43.595776Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Sed/index.html", "level": "info", "timestamp": "2023-12-30T19:01:44.427840Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.432807Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433200Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433415Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433629Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433754Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.433853Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.434403Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.434718Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Sed/2023/SED231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:46.434899Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Skb/index.html", "level": "info", "timestamp": "2023-12-30T19:01:48.158133Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.890516Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.890997Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.891325Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.891962Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892219Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892396Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892580Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Skb/2023/SKB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:50.892825Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Tyb/index.html", "level": "info", "timestamp": "2023-12-30T19:01:57.157213Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231228.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.520607Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231224.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.520861Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231223.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521138Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231217.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521276Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231216.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521455Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231210.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.521895Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231209.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.522230Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231203.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.522534Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Tyb/2023/TYB231202.zip", "level": "info", "timestamp": "2023-12-30T19:01:59.523686Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading and extracting files from http://www.jrdb.com/member/datazip/Hjc/index.html", "level": "info", "timestamp": "2023-12-30T19:02:00.453931Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231228.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.975878Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231224.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976164Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231223.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976308Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231217.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976553Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231216.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976674Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231210.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.976843Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231209.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.977245Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231203.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.977676Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}
# {"event": "Downloading http://www.jrdb.com/member/datazip/Hjc/2023/HJC231202.zip", "level": "info", "timestamp": "2023-12-30T19:02:03.978182Z", "logger": "JapanHorseRaceAnalytics.file_downloader"}

# %%
spark = SparkSession.builder \
    .appName("PythonNotebookSparkSession") \
    .config("spark.sql.warehouse.dir", "/Users/hankehly/Projects/JapanHorseRaceAnalytics/spark-warehouse") \
    .config("spark.jars", "/Users/hankehly/Projects/JapanHorseRaceAnalytics/jars/postgresql-42.7.1.jar") \
    .config("spark.executor.extraClassPath", "/Users/hankehly/Projects/JapanHorseRaceAnalytics/jars/postgresql-42.7.1.jar") \
    .config("spark.driver.extraClassPath", "/Users/hankehly/Projects/JapanHorseRaceAnalytics/jars/postgresql-42.7.1.jar") \
    .enableHiveSupport() \
    .getOrCreate()
# Out:
# 24/02/04 15:08:24 WARN Utils: Your hostname, Hanks-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.40.105 instead (on interface en0)
# 24/02/04 15:08:24 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 24/02/04 15:08:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/02/04 15:08:25 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# # Record which files were downloaded
# # Import data into Postgres

# %% [markdown]
# ## Todo: incremental processing

# %%
# from pyspark.sql.types import StringType
# df_files = spark.createDataFrame(os.listdir(download_dir), StringType())
# df_files.write.mode("overwrite").format("jdbc").options(
#     url="jdbc:postgresql://localhost:5432/jrdb",
#     user="admin",
#     password="admin",
#     driver="org.postgresql.Driver",
#     dbtable="jrdb_raw.processed_files",
# ).save()

# df_processed_files = (
#     spark.read.jdbc(
#         url="jdbc:postgresql://localhost:5432/jrdb",
#         table="jrdb_raw.processed_files",
#         properties={
#             "user": "admin",
#             "password": "admin",
#             "driver": "org.postgresql.Driver",
#         },
#     )
#     .alias("df_processed_files")
#     .select("value")
# )

# df_data = (
#     spark.read.format("binaryFile")
#     .load("file:///Users/hankehly/Projects/JapanHorseRaceAnalytics/downloads/BAC*.txt")
#     .withColumn("filename", f.element_at(f.split(f.col("path"), "/"), -1))
#     # .rdd.flatMap(lambda x: x[0].splitlines())
#     # .show(truncate=False)
# )

# unprocessed_files = df_data.join(df_processed_files, df_data.filename == df_processed_files.value, "left_anti")
# unprocessed_files.show(truncate=False)

# %%
def etl(
    spark,
    schema_path: str,
    data_path: str | List[str],
    dbtable: str,
    surrogate_key_name: str,
):
    logger.info(f"Processing dataset {dbtable}")
    schema = load_schema(schema_path)
    logger.info("Creating PySpark DataFrame")
    df = (
        spark.read.format("binaryFile")
        .load(data_path)
        .select("content")
        .rdd.flatMap(lambda x: x[0].splitlines())
        .map(functools.partial(parse_line, schema=schema))
        .toDF(create_pyspark_schema(schema))
        # Todo: monotonic increasing id does not mean files with lower dates will have lower ids!
        .withColumn(surrogate_key_name, f.monotonically_increasing_id())
        # Returns the wrong file name..
        # .withColumn("input_file_name", f.input_file_name())
    )
    logger.info("Writing to data warehouse")
    df.write.mode("overwrite").saveAsTable(dbtable)

# %% [markdown]
# The following TYB file in the annual pack contains null byte characters. Its daily file counterpart does not, so we must replace it before the file can be processed.
# * TYB060121.txt
#
# Starting 2021-09-04, TYB files are duplicated in the annual pack. One file name contains a "_t" while the other does not. The daily file counterpart contains the same information as the annual pack file whose name does not contain a "_t" in it. In addition, some of the "_t" files contain null byte characters. The following files are affected. All files with "_t" in the name are ignored when parsing.
# * TYB210904_t.txt
# * TYB210905_t.txt
# * TYB210911_t.txt

# %%
datasets = [
    "KAB",
    "BAC",
    "KYI",
    "UKC",
    "OZ",
    "OW",
    "OU",
    "OT",
    "OV",
    "CYB",
    "CHA",
    "SKB",
    "HJC",
    "SED",  # Run remove_sed_duplicates.sql after loading this dataset
    "TYB",
]

schema_name = "jhra_raw"
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema_name}")

for dataset in datasets:
    schema_path = f"schemas/{dataset}.yaml"
    dbtable = f"{schema_name}.raw_jrdb__{dataset.lower()}"
    surrogate_key_name = f"{dataset.lower()}_sk"
    # TYB is a special case because the file names are not consistent
    if dataset == "TYB":
        tyb_pattern = re.compile(r"TYB\d{6}\.txt$")
        tyb_files_glob = Path(download_dir).glob("TYB*.txt")
        tyb_files = [
            str(file) for file in tyb_files_glob if tyb_pattern.match(file.name)
        ]
        etl(
            spark,
            schema_path=schema_path,
            data_path=tyb_files,
            dbtable=dbtable,
            surrogate_key_name=surrogate_key_name,
        )
    else:
        etl(
            spark,
            schema_path=schema_path,
            data_path=str(Path(download_dir).joinpath(f"{dataset}*.txt")),
            dbtable=dbtable,
            surrogate_key_name=surrogate_key_name,
        )
# Out:
# 24/02/04 15:08:30 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 24/02/04 15:08:30 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# {"event": "Processing dataset jhra_raw.raw_jrdb__kab", "level": "info", "timestamp": "2024-02-04T06:08:30.929864Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:08:30.937790Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:08:36.155540Z", "logger": "__main__"}
# 24/02/04 15:08:36 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/02/04 15:08:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:08:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:38 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# 24/02/04 15:08:38 WARN HiveConf: HiveConf of name hive.internal.ss.authz.settings.applied.marker does not exist
# 24/02/04 15:08:38 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 24/02/04 15:08:38 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 24/02/04 15:08:38 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException
# {"event": "Processing dataset jhra_raw.raw_jrdb__bac", "level": "info", "timestamp": "2024-02-04T06:08:38.823705Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:08:38.832313Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:08:42.708423Z", "logger": "__main__"}
# 24/02/04 15:08:42 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:08:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__kyi", "level": "info", "timestamp": "2024-02-04T06:08:44.573418Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:08:44.630455Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:08:48.256272Z", "logger": "__main__"}
# 24/02/04 15:08:48 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:48 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:48 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:08:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:08:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:08:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:08:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:08:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:08:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:08 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:08 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:08 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:08 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__ukc", "level": "info", "timestamp": "2024-02-04T06:09:09.841238Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:09:09.846253Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:09:13.370553Z", "logger": "__main__"}
# 24/02/04 15:09:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__oz", "level": "info", "timestamp": "2024-02-04T06:09:18.316593Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:09:18.319414Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:09:21.603955Z", "logger": "__main__"}
# 24/02/04 15:09:21 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:21 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:21 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__ow", "level": "info", "timestamp": "2024-02-04T06:09:24.281126Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:09:24.283643Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:09:27.424999Z", "logger": "__main__"}
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:27 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:29 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__ou", "level": "info", "timestamp": "2024-02-04T06:09:29.642156Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:09:29.644846Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:09:32.531862Z", "logger": "__main__"}
# 24/02/04 15:09:32 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:32 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:32 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:32 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:34 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__ot", "level": "info", "timestamp": "2024-02-04T06:09:35.957125Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:09:35.959701Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:09:38.925222Z", "logger": "__main__"}
# 24/02/04 15:09:39 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:39 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:39 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:40 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:40 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:40 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:40 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:40 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:41 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:41 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:41 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:41 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:41 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:42 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:42 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:42 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:42 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:42 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:44 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:44 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:44 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:44 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:44 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__ov", "level": "info", "timestamp": "2024-02-04T06:09:46.487664Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:09:46.490637Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:09:49.418433Z", "logger": "__main__"}
# 24/02/04 15:09:49 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:49 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:49 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:09:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:09:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# ...
# {"event": "Processing dataset jhra_raw.raw_jrdb__sed", "level": "info", "timestamp": "2024-02-04T06:10:52.209073Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:10:52.226052Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:10:55.863639Z", "logger": "__main__"}
# 24/02/04 15:10:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:10:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:10:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:10:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:10:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:10:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:10:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:10:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:10:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:10:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:10:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:00 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:00 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:00 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:00 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:01 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:02 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:03 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:04 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# {"event": "Processing dataset jhra_raw.raw_jrdb__tyb", "level": "info", "timestamp": "2024-02-04T06:11:08.082856Z", "logger": "__main__"}
# {"event": "Creating PySpark DataFrame", "level": "info", "timestamp": "2024-02-04T06:11:08.089980Z", "logger": "__main__"}
# {"event": "Writing to data warehouse", "level": "info", "timestamp": "2024-02-04T06:11:10.913316Z", "logger": "__main__"}
# 24/02/04 15:11:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 24/02/04 15:11:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %% [markdown]
# # Convert codes to CSV format
#
# Copy and paste text from the code web pages into the following block, run cell, and save as a CSV file in the `seeds` directory.
#
# * [ＪＲＤＢデータコード表](http://www.jrdb.com/program/jrdb_code.txt)
# * [脚元コード表（2017.02.20）](http://www.jrdb.com/program/ashimoto_code.txt)
# * [馬具コード表（2017.07.02）](http://www.jrdb.com/program/bagu_code.txt)
# * [特記コード表（2008.02.23）](http://www.jrdb.com/program/tokki_code.txt)
# * [系統コード表（2003.05.15）](http://www.jrdb.com/program/keito_code.txt)
# * [調教コースコード表（2009.10.09）](http://www.jrdb.com/program/cyokyo_course_code.txt)
# * [追い状態コード表（2008.09.28）](http://www.jrdb.com/program/oi_code.txt)

# %%
code_text = """
01      流す
02      余力あり
03      終い抑え
04      一杯
05      バテる
06      伸びる
07      テンのみ
08      鋭く伸び
09      強目
10      終い重点
11      ８分追い
12      追って伸
13      向正面
14      ゲート
15      障害練習
16      中間軽め
17      キリ
21      引っ張る
22      掛かる
23      掛リバテ
24      テン掛る
25      掛り一杯
26      ササル
27      ヨレル
28      バカつく
29      手間取る
99      その他
"""

result = []
for line in code_text.strip().splitlines():
    result.append(line.strip().split())

print(pd.DataFrame(result).to_csv(index=False, header=False))
# Out:
# 01,流す
# 02,余力あり
# 03,終い抑え
# 04,一杯
# 05,バテる
# 06,伸びる
# 07,テンのみ
# 08,鋭く伸び
# 09,強目
# 10,終い重点
# 11,８分追い
# 12,追って伸
# 13,向正面
# 14,ゲート
# 15,障害練習
# 16,中間軽め
# 17,キリ
# 21,引っ張る
# 22,掛かる
# 23,掛リバテ
# 24,テン掛る
# 25,掛り一杯
# 26,ササル
# 27,ヨレル
# 28,バカつく
# 29,手間取る
# 99,その他
